# %% [markdown]
# ## Create Directory
# #### /home/tuhin/Desktop/image_processing
# Inside image_processing there are 5 folders images and labels.</br>
# images => Here put all the images and after run the below code the image will be renamed.</br>
# labels => After run the below code the label will create here.</br>
# test => test images and labels</br>
# train => train images and labels</br>
# valid => valid images and labels</br>
# <span style="color:red">Note:</span> before run the below code place all the image folders inside images

# %% [markdown]
# ## Image and Label Processing and after Spliting Dataset in 70%, 20% and 10%

# %%
import os
import random
import shutil

# Path to the directory containing the folders
directory_path = '/home/tuhin/Desktop/image_processing/images'

# Get all directory names within the specified directory
folder_names = [folder for folder in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, folder))]

# Print each folder name using a for loop
for folder_name in folder_names:
    # Path to the directory containing the images
    image_directory = '/home/tuhin/Desktop/image_processing/images/' + folder_name
    label_directory = '/home/tuhin/Desktop/image_processing/labels'
    train_directory = '/home/tuhin/Desktop/image_processing/train'
    valid_directory = '/home/tuhin/Desktop/image_processing/valid'
    test_directory = '/home/tuhin/Desktop/image_processing/test'
    
    # Starting point for renaming
    counter = 1
    
    # Prefix for the file names
    prefix_counter = folder_name + "_"
    
    # Content for the text files
    label_content = "0 0.5 0.5 1 1"
    
    # Create train, valid, and test directories if they don't exist
    for directory in [train_directory, valid_directory, test_directory]:
        if not os.path.exists(directory):
            os.makedirs(directory)
    
    # Get a list of all files in the image directory
    files = os.listdir(image_directory)
    
    # Filter only image files (assuming image extensions like jpg, png, etc.)
    image_files = [f for f in files if f.endswith(('.jpg', '.png', '.jpeg'))]
    
    # Sort the image files
    image_files.sort()
    
    # Shuffle the image files randomly
    random.shuffle(image_files)
    
    # Calculate the number of files for train, valid, and test
    total_files = len(image_files)
    train_count = int(total_files * 0.7)
    valid_count = int(total_files * 0.2)
    test_count = total_files - train_count - valid_count
    
    # Rename each image file and create corresponding text files
    for old_name in image_files:
        # Get the file extension
        _, extension = os.path.splitext(old_name)
        
        # Form the new file name
        new_name = f"{prefix_counter}{counter}" + extension
        
        # Construct the full paths for image and label files
        old_image_path = os.path.join(image_directory, old_name)
        new_image_path = os.path.join(image_directory, new_name)
        label_path = os.path.join(label_directory, f"{prefix_counter}{counter}.txt")
        
        # Print statements for debugging
        print(f"Renaming {old_image_path} to {new_image_path}")
        
        # Rename the image file
        os.rename(old_image_path, new_image_path)
        
        # Print statements for debugging
        print(f"Creating label file: {label_path}")
        
        # Write the label content to the text file
        with open(label_path, 'w') as label_file:
            label_file.write(label_content)
        
        # Determine destination directory based on file count
        if counter <= train_count:
            dest_directory = train_directory
        elif counter <= train_count + valid_count:
            dest_directory = valid_directory
        else:
            dest_directory = test_directory
        
        # Move images and labels to appropriate directories
        dest_image_path = os.path.join(dest_directory, 'images', new_name)
        dest_label_path = os.path.join(dest_directory, 'labels', f"{prefix_counter}{counter}.txt")
        
        shutil.move(new_image_path, dest_image_path)
        shutil.move(label_path, dest_label_path)
        
        # Increment the counter
        counter += 1
# Out:
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy13_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_1.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_1.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy5_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_2.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_2.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy7_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_3.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_3.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy12_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_4.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_4.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy15_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_5.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_5.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy3_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_6.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_6.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy8_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_7.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_7.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy14_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_8.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_8.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy9_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_9.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_9.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy16_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_10.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_10.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy6_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_11.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_11.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy11_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_12.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_12.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy4_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_13.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_13.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy10_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_14.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_14.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy2_.jpg to /home/tuhin/Desktop/image_processing/images/healthy_cassava/healthy_cassava_15.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_cassava_15.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (6).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_1.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_1.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (5).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_2.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_2.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (8).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_3.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_3.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (7).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_4.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_4.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (12).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_5.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_5.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (9).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_6.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_6.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (3).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_7.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_7.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (4).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_8.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_8.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (11).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_9.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_9.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (15).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_10.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_10.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (13).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_11.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_11.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (1).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_12.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_12.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (14).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_13.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_13.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (10).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_14.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_14.txt
# Renaming /home/tuhin/Desktop/image_processing/images/healthy_grape/image (2).jpg to /home/tuhin/Desktop/image_processing/images/healthy_grape/healthy_grape_15.jpg
# Creating label file: /home/tuhin/Desktop/image_processing/labels/healthy_grape_15.txt
