# %% [markdown]
# ## Rename Images

# %%
import os
import glob

# Path to the directory containing the folders
directory_path = '/home/tuhin/Desktop/YOLO_Image_Processing/Images'

# Function to rename images in a folder
def rename_images(folder_path, folder_name):
    # List all image files in the folder
    image_files = glob.glob(os.path.join(folder_path, '*.png')) + glob.glob(os.path.join(folder_path, '*.jpg')) + glob.glob(os.path.join(folder_path, '*.jpeg'))

    # Create a list of new file names
    new_names = [os.path.join(folder_path, f'{folder_name}_{i+1}{os.path.splitext(file)[1]}') for i, file in enumerate(image_files)]

    # Perform renaming only if there are no conflicts
    for old_name, new_name in zip(image_files, new_names):
        if not os.path.exists(new_name):
            try:
                os.rename(old_name, new_name)
                print(f'Renamed: {old_name} -> {new_name}')
            except Exception as e:
                print(f'Error renaming {old_name}: {e}')
        else:
            print(f'Conflict detected: {new_name} already exists, skipping renaming.')

# Iterate over each folder
for folder_name in os.listdir(directory_path):
    print(f'Processing folder: {folder_name}')
    folder_path = os.path.join(directory_path, folder_name)
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        rename_images(folder_path, folder_name)
# Out:
# Processing folder: healthy_cassava
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_1.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_2.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_3.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_4.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_5.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_6.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_7.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_8.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_9.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_10.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_11.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_12.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_13.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_14.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_15.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_16.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_17.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_18.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_19.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_20.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_21.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_22.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_23.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_24.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_25.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_26.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_27.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_28.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_29.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_30.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_31.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_32.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_33.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_34.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_35.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_36.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_37.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_38.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_39.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_40.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_41.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_42.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_43.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_44.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_45.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_46.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_47.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_48.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_49.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_50.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_51.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_52.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_53.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_54.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_55.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_56.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_57.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_58.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_59.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_60.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_61.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_62.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_63.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_64.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_65.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_66.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_67.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_68.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_69.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_70.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_71.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_72.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_73.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_74.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_75.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_76.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_77.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_78.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_79.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_80.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_81.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_82.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_83.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_84.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_85.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_86.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_87.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_88.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_89.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_90.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_91.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_92.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_93.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_94.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_95.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_96.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_97.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_98.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_99.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_100.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_101.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_102.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_103.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_104.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_105.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_106.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_107.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_108.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_109.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_110.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_111.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_112.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_113.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_114.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_115.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_116.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_117.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_118.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_119.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_120.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_121.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_122.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_123.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_124.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_125.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_126.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_127.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_128.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_129.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_130.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_131.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_132.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_133.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_134.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_135.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_136.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_137.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_138.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_139.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_140.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_141.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_142.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_143.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_144.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_145.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_146.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_147.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_148.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_149.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_150.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_151.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_152.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_153.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_154.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_155.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_156.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_157.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_158.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_159.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_160.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_161.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_162.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_163.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_164.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_165.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_166.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_167.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_168.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_169.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_170.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_171.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_172.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_173.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_174.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_175.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_176.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_177.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_178.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_179.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_180.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_181.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_182.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_183.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_184.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_185.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_186.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_187.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_188.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_189.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_190.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_191.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_192.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_193.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_194.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_195.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_196.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_197.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_198.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_199.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_200.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_201.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_202.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_203.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_204.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_205.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_206.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_207.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_208.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_209.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_210.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_211.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_212.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_213.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_214.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_215.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_216.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_217.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_218.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_219.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_220.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_221.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_222.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_223.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_224.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_225.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_226.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_227.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_228.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_229.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_230.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_231.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_232.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_233.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_234.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_235.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_236.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_237.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_238.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_239.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_240.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_241.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_242.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_243.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_244.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_245.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_246.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_247.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_248.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_249.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_250.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_251.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_252.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_253.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_254.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_255.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_256.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_257.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_258.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_259.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_260.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_261.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_262.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_263.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_264.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_265.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_266.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_267.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_268.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_269.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_270.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_271.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_272.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_273.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_274.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_275.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_276.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_277.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_278.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_279.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_280.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_281.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_282.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_283.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_284.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_285.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_286.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_287.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_288.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_289.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_290.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_291.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_292.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_293.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_294.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_295.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_296.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_297.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_298.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_299.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_300.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_301.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_302.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_303.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_304.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_305.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_306.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_307.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_308.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_309.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_310.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_311.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_312.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_313.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_314.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_315.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_316.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_317.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_318.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_319.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_320.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_321.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_322.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_323.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_324.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_325.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_326.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_327.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_328.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_329.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_330.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_331.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_332.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_333.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_334.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_335.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_cassava/healthy_cassava_336.jpg already exists, skipping renaming.
# ...
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1537.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1538.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1539.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1540.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1541.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1542.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1543.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1544.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1545.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1546.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1547.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1548.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1549.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1550.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1551.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1552.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1553.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1554.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1555.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1556.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1557.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1558.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1559.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1560.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1561.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1562.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1563.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1564.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1565.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1566.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1567.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1568.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1569.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1570.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1571.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1572.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1573.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1574.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1575.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1576.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1577.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1578.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1579.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1580.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1581.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1582.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1583.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1584.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1585.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1586.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1587.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1588.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1589.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1590.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1591.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1592.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1593.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1594.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1595.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1596.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1597.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1598.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1599.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1600.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1601.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1602.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1603.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1604.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1605.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1606.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1607.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1608.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1609.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1610.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1611.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1612.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1613.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1614.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1615.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1616.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1617.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1618.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1619.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1620.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1621.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1622.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1623.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1624.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1625.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1626.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1627.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1628.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1629.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1630.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1631.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1632.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1633.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1634.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1635.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1636.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1637.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1638.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1639.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1640.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1641.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1642.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1643.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1644.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1645.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1646.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1647.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1648.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1649.jpg already exists, skipping renaming.
# Conflict detected: /home/tuhin/Desktop/YOLO_Image_Processing/Images/healthy_apple/healthy_apple_1650.jpg already exists, skipping renaming.

# %% [markdown]
# ## Create Directory
# #### /home/tuhin/Desktop/image_processing
# Inside image_processing there are 5 folders images and labels.</br>
# images => Here put all the images folders.</br>
# labels => Here put all the labels folders.</br>
# test => test images and labels (inside create two folders images and labels)</br>
# train => train images and labels (inside create two folders images and labels)</br>
# valid => valid images and labels (inside create two folders images and labels)</br>
# <span style="color:red">Note:</span> before run the below codes place all the image and label folders inside images and labels and make sure test, train and valid are empty.

# %% [markdown]
# ## Keep only 100 images from each directory <span style="color:red">Optional</span>

# %%
import os

# Path to the directory containing the folders
directory_path = '/home/tuhin/Desktop/image_processing/images'
image_limit = 100

# Get all directory names within the specified directory
folder_names = [folder for folder in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, folder))]

# Iterate over each folder
for folder_name in folder_names:
    folder_path = os.path.join(directory_path, folder_name)
    
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    
    # Filter only image files (assuming image extensions like jpg, png, etc.)
    image_files = [f for f in files if f.endswith(('.jpg', '.png', '.jpeg'))]
    
    # Sort the image files
    image_files.sort()
    
    # Keep only the first n images, delete the rest
    for image_file in image_files[image_limit:]:
        os.remove(os.path.join(folder_path, image_file))

# %% [markdown]
# ## Update Label Indexing

# %%
import os

# Define the directory path
directory = '/home/tuhin/Desktop/image_processing/labels'

# List to store folder names
folder_names_list = []

# Variable to store the total number of labels
total_labels = 0

# Function to replace the first value in each line of a text file
def replace_first_value(file_path, replace_value):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    with open(file_path, 'w') as file:
        for line in lines:
            values = line.strip().split()
            if values:
                values[0] = replace_value
                new_line = ' '.join(values) + '\n'
                file.write(new_line)

# Iterate over each folder in the directory
for idx, foldername in enumerate(os.listdir(directory)):
    folder_path = os.path.join(directory, foldername)
    if os.path.isdir(folder_path):
        replace_value = str(idx)
        folder_names_list.append(foldername)
        print(f"Processing folder '{foldername}', replace_value: {replace_value}")
        total_labels += 1
        # Iterate over each file in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith('.txt'):
                file_path = os.path.join(folder_path, filename)
                replace_first_value(file_path, replace_value)

# Print the list of folder names and the total number of labels
print()
print("List of folder names:", folder_names_list)
print("Total number of labels:", total_labels)
# Out:
# Processing folder 'pest_snail', replace_value: 0
# Processing folder 'pest_weevil', replace_value: 1
#
# List of folder names: ['pest_snail', 'pest_weevil']
# Total number of labels: 2

# %% [markdown]
# ## Spliting Dataset in 70%, 20% and 10%

# %%
import os
import random
import shutil

# Define directory paths
image_source_dir = '/home/tuhin/Desktop/image_processing/images'
label_source_dir = '/home/tuhin/Desktop/image_processing/labels'
train_dir = '/home/tuhin/Desktop/image_processing/train'
valid_dir = '/home/tuhin/Desktop/image_processing/valid'
test_dir = '/home/tuhin/Desktop/image_processing/test'

# Create train, validation, and test directories if they don't exist
for directory in [train_dir, valid_dir, test_dir]:
    os.makedirs(os.path.join(directory, 'images'), exist_ok=True)
    os.makedirs(os.path.join(directory, 'labels'), exist_ok=True)

# Get a list of all subdirectories in the image source directory
subdirectories = next(os.walk(image_source_dir))[1]

# Iterate over each subdirectory
for subdirectory in subdirectories:
    # Get list of image files in the current subdirectory
    image_files = os.listdir(os.path.join(image_source_dir, subdirectory))
    
    # Shuffle the list of image files
    random.seed(42)  # For reproducibility
    random.shuffle(image_files)
    
    # Calculate the number of files for train, validation, and test
    total_files = len(image_files)
    train_count = int(total_files * 0.7)
    valid_count = int(total_files * 0.2)
    test_count = total_files - train_count - valid_count
    
    # Split the list of image files into train, validation, and test sets
    train_files = image_files[:train_count]
    valid_files = image_files[train_count:train_count + valid_count]
    test_files = image_files[train_count + valid_count:]
    
    # Function to move files
    def move_files(files, source_dir, dest_dir):
        for file_name in files:
            # Move images
            source_image_path = os.path.join(source_dir, file_name)
            dest_image_path = os.path.join(dest_dir, 'images', file_name)
            shutil.move(source_image_path, dest_image_path)
            
            # Move corresponding labels
            label_file_name = os.path.splitext(file_name)[0] + '.txt'
            source_label_path = os.path.join(label_source_dir, subdirectory, label_file_name)
            dest_label_path = os.path.join(dest_dir, 'labels', label_file_name)
            shutil.move(source_label_path, dest_label_path)
    
    # Move files to train directory
    move_files(train_files, os.path.join(image_source_dir, subdirectory), train_dir)
    
    # Move files to validation directory
    move_files(valid_files, os.path.join(image_source_dir, subdirectory), valid_dir)
    
    # Move files to test directory
    move_files(test_files, os.path.join(image_source_dir, subdirectory), test_dir)

print("Dataset split successfully into train, validation, and test sets.")
# Out:
# Dataset split successfully into train, validation, and test sets.
